# %% [markdown]
# # NLP Course | Final Project
# by Millis Sahar
#
# <br><br><br>
# <br><br><br>
# <a href='https://www.loom.com/share/a9096c8a9cc3480388a0b6e1619f7123'>link</a> to video presentation.
# <br><br><br>

# %% [markdown]
# ## Notebook Edit Helpers

# %% [markdown]
# Show Youtube videos in notebook:

# %%
from IPython.core.display import display, HTML
from IPython.display import YouTubeVideo

# %% [markdown]
# <br><br><br>

# %% [markdown]
# # Goals
#
# I had a few ideas for a final project - so tried them all :)
#
#     1. Accidental Session Classification
#     2. Short Question Answering system
#     3. Generating Movie Trailer's
#     4. Generate Schizophrenic Speech
#     5. Create a Chatbot
#
# Some have been achived.. And for some, while being a dead end, I got to learn a lot.
#
# But mostly I had to read so  **many  articles** ;)
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %% [markdown]
# # Goal #1 - Achieved!
#
# A *Cost-Sensitive Sequence Binary-Classification* with an imbalnced dataset.
#
# After finishing my analysis these are the unusual problems I'll have to face:
# - Short Sequence Classification
# - Emoji Embeddings
# - Imbalnced
#
# I have decided to work with **BERT** : Tokenize => Embeddings => Classification
#
#
# - **Why not using ML/Statistics?**
#     It has no understanding of context.
#     It could work, but it's more like writing the rules by hand based on statistics, instead of generalizing.
#
#
# - **Why not using RNNs(LSTM/GRU)?**
#     It will get nice results.
#     It takes more time to train, compare to AutoEncoders.
#     It would probably achived "the same" results on this dataset.
#     **It was important for me to display my abilities using SOTA models.**

# %% [markdown]
# ### Code
#
# - Explanatory Analysis
#   <a href='https://colab.research.google.com/drive/1pdP4J6Sc5wQzzB99zrlE6DyP9xU64DdA?usp=sharing'>Link</a> to a Google Colab notebook containing all my analysis and initial data preperation.
#
#
# - Model & Evaluation
#   <a href='https://colab.research.google.com/drive/1HYeRmbu3lB-QePsxa9WXInMfl3nthXpk?usp=sharing'>Link</a> to a Google Colab notebook containing my model, traininig and evaluation.
#
# <br><br><br>

# %% [markdown]
# ### Future Work
# <br><br>
#
#
# - **Hyperparameters Tuning**
#     Search for the optimal hyperparameters.
#
# <br>
#
# - **Different Architecture/Embeddings**
#     Maybe different models would preform better, although I doubt it, perhaps different embeddings would better represent the vocabulary.
#
# <br>
#
# - **Emojis**
#     I would have use some emojis embeddings, instead of their description.
#     For example, use **emoji2vec** package.
# ![image.png](attachment:image.png)
#
# <br>
#
# - **Imbalanced and Dissimilar**
#     I will have to use more Cost-Sensitive methods on BERT.
#     For example, wandb.ai provides that service.  Or use some academic methos, like described <a href='https://www.aclweb.org/anthology/D19-5018v2.pdf'>here</a>.
#
# <br>
#
# - **Data Augmentation**
#     In case of poor results, I would try to use text augmentation techniques to create more data.
#
#     - Thesaurus
#     - Word Embeddings
#     - Back Translation
#     - Text Generation
#     or just using nlpaug package :)
#
# <br>
#
# - **Oversampling and Undersampling**
#     In case of poor results, I would try to use these technique to ease off the imbalance between the classes.
#     I would use the imblearn package **after tokenizing**, and perform Over-Sampling (SMOTE) followed by Under-Sampling (Tomek links).
#
# <br>
#
# - **Short Sentences**
#     A big problem is to classify the short sentences.
#     Some of them will be uncleared even to the human eye.
#     Thus, even if I'll create a better model, maybe even use ML, it would just overfit to *this dataset.*
#     Nevertheless, without a better dataset representation **these ambiguities** would be impossible.
# ![image-2.png](attachment:image-2.png)
#
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %% [markdown]
# # Goal #2 - Partially Achieved!
# Create a *Short Question Answering* system.
#
# First I tried to work on the <a href='https://rajpurkar.github.io/SQuAD-explorer/'>SQuAD</a> dataset.
# But after figure out my workflow I went another way.
#
# ![image-11.png](attachment:image-11.png)
# ![image-12.png](attachment:image-12.png)
# ![image-13.png](attachment:image-13.png)
#
#
# #### So I basicly tried to create to two components:
# - **Q&A model** :
#     <a href='https://colab.research.google.com/drive/19eDyGwcmBueAmNKcPOXz5uVEI93djnfR?usp=sharing'>Here</a> is my Colab notebook, will be based on bert.
#
#
# - **Semantic model**
#     For some reason, I had really hard time figuring this out.
#     <a href='https://colab.research.google.com/drive/1_DXkFPjUnLEGTOpCS4SwLKPDmsdImqna?usp=sharing'>Here</a> is my Colab notebook with all of me attempts.
#
# <br>
#
# **As I mentioned, I wasn't able to achieved the goal.**
# It's due to my inability to find a good similarity model.
#
# <br><br><br>
# <br><br><br>

# %% [markdown]
# # Goal #3 - Not Achieved!
# Generating trailer's text for movies.
#
# ![image.png](attachment:image.png)
#
# The **best article** got to read is <a href='https://ieeexplore.ieee.org/abstract/document/8358211'>Smart trailer</a>: Automatic generation of movie trailer using only subtitles.
# (<a href='https://drive.google.com/file/d/1dzzeOibD3i2KFaXjZ6kIeNhLMldCC0My/view?usp=sharing'>Download link</a>)
#
#
# Also read these articles and research on more approaches:
# - <a href='https://s3-eu-central-1.amazonaws.com/ucu.edu.ua/wp-content/uploads/sites/8/2019/12/Orest-Rehusevych.pdf'>movie2trailer</a>: Unsupervised trailer generation using Anomaly detection
# - <a href='https://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.657.2917&rep=rep1&type=pdf'>Vid2Trailer</a>: Automatic Trailer Generation
# - <a href='https://dl.acm.org/doi/abs/10.1145/2807442.2807502'>SceneSkim</a> by Amy Pavel, that use short summaries
# - <a href='https://dl.acm.org/doi/10.1145/1178677.1178709'>Selects Shots</a> by Alan F. Smeaton
# And a lot more...
#
# For creating **my own model** I had to get my hands on tagged datasets.
#
# Movie subtitles was not the problem.
# However, datasets of trialer's subtitles is not avialable.
# Currently, The only approch possible is to crawl a few websites to get it.
#
# Examples:
# - <a href='https://downsub.com/'>downsub</a>: Download and save any subtitles from Youtube
# - <a href='https://www.subtitledtrailers.com/'>subtitledtrailers</a>: Trailers and Shorts with English and French subtitles
# And more..
#
# This would probably breach a few laws and takes a lot of time.
# Time that I'm not concentrating on NLP...
#
# <br><br><br>
# <br><br><br>

# %% [markdown]
# # Goal #4 - partialy Achieved!
# Generate Schizophrenic speech - focusing on derailing
#
# **Defenition:**
# <i>
# For people who may be experiencing a thought disorder, derailment occurs when they slip further and further away from the original point of a discussion.
# Derailing thoughts can just wander off and never return.
# </i>
#
# This was kfir's idea, and I took the challenge...
#
# Let's understand what Schizophrenia is:

# %%
YouTubeVideo('tYiTznmuSu4', width=500, height=300)

# %% [markdown]
# <br><br><br>
#
# **Let's see a live example of derailing:**

# %%
YouTubeVideo('u2vMnyTiwp4', width=500, height=300)

# %% [markdown]
# **He's speech:**
#
# Like in the daytime when I go outside in the sun, I used to show my friends—
# they hadn't seen before—like the halos—halo. When I was 19 when I was a preacher and I
# had my [indiscernible], I used to see a little light on my shadow on the ground in the daytime.
# And now, ever since then, the light is coming further down on my body around my shadow.
# It's over my body but around my shadow like you see the light which is your halo, I mean your aura.
# And that's why everybody can't see that but if you—if you—If you've got
# someone doing the drugs, we'd say—I don't know what's for real. I know from what I see
# but I don't know if it's for real or not. So that's why you see people different.
# And say like they have an anointing, sometimes when I come outside, I can see—
# when I look at the trees, the wind starts blowing. 'Cause we get oxygen from the plants,
# and we get we give them carbon dioxide. And so it's the wind usually blows sometimes
# but it don't blow all the time. Like when I'm in the house a long time, it blow real strong.

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# So it's basicaly a generative text model.
#
# I's try to generate some text with different NLP methods:
# - N-Grams
# - LSTM
# - GPT2
# - GAN
#
# <br><br>
#
#
# ## Code
#
# I'll be working on the Harry Potter books.
#
# - Generate using Ngrams
# - Generate using RNNs
# - Generate using GPT2
#
# <a href='https://colab.research.google.com/drive/1br6EHyRR3p_FCbPXUup3uILVBWV9pPuE?usp=sharing'>Here is my learning process - in a Google Colab notebook.</a>
#
# With my new learned skiils I'll try to generate Schizophrenic speeches.

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ### Finetune GPT-2 with pytorch
#
# My final goal is to create a Scyzofrenia speech, and this conversation is less like a book, and more like a script, of a number of long sentences.
#
# So I acquired a huge dataset of Jokes, and I'm trying to generate that kind of text.
#
# Due to the computetinal power of my laptop, you can see my code in <a href='https://colab.research.google.com/drive/1rOmSGBXWe30ueXMQpRtW4-dGCqdnJeAp?usp=sharing'>my Google Colab notebook</a>.
# <br>

# %% [markdown]
# ##### Results:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# And it works nicely. You can see the model understand the context, and the structure of a joke.

# %% [markdown]
# **Conclusions:**
# -  In case I have a dataset of Scyzofrenia talks, I could finetune GPT-2 to generate text.
# -  But the problem I don't have enough of these talks.
# - I tried to do this with Keras, but it's way easier with Pytorch.

# %% [markdown]
# **References:**
#
# - <a href='https://huggingface.co/blog/how-to-generate'>huggingface: How to generate text: using different decoding methods for language generation with Transformers</a>
#
#
# - <a href='https://towardsdatascience.com/too-powerful-nlp-model-generative-pre-training-2-4cc6afb6655'>Too powerful NLP model (GPT-2)</a>
#
#
# - <a href='https://towardsdatascience.com/train-a-gpt-2-transformer-to-write-harry-potter-books-edf8b2e3f3db'>Train a GPT-2 Transformer to write Harry Potter Books!</a>
#
#
# - <a href='https://github.com/priya-dwivedi/Deep-Learning/tree/master/GPT2-HarryPotter-Training'>GPT2-HarryPotter-Training</a>
#
#
# - <a href='https://colab.research.google.com/drive/1VI3oBIOQYsym2x5oOux7DTNhpdR0r4uw'>DeepFaking the News with NLP and Transformer Models</a>
#
#
# - <a href='https://medium.com/swlh/learning-to-write-language-generation-with-gpt-2-2a13fa249024'>Learning to Write: Language Generation With GPT-2</a>
#
#
# - <a href='https://papers.nips.cc/paper/7181-attention-is-all-you-need.pdf'>Attention Is All You Need</a>
#
#
# - <a href='https://medium.com/@stasinopoulos.dimitrios/a-beginners-guide-to-training-and-generating-text-using-gpt2-c2f2e1fbd10a'>A beginner’s guide to training and generating text using GPT2</a>
#
# <br><br><br>
# <br><br><br>

# %% [markdown]
# # GPT2 - Schizophrenia & Derilling
#
# In order to generate Schizophrenia speech I need a bug dataset of that, but I don't have it.
# If I would have a huge dataset I could use an AutoEncoder to do this for me.
# So would I be able to create a GPT-2 model that will generate these talks for me?
#
# Let's try...
#
# **Ideas:**
# 1. Sampling with a different values for top_k and top_p.
# 2. Adding words to help the model derilled for the subject.
# 3. Changing the Loss function
# 4. Use a classifier as the Loss function
#
# Sadly, the first 3 didn't work.
# The third one would have would if I could define a good Loss function, but I could not achived that, cuz how would you measure Derriling.
# This leads me to the next issue, **How would I check the correctness of the new generated text?** or in other word, how would I measure the Derreling affect.
#
# **So I have to get creative!**

# %% [markdown]
# <br><br>
# ___
# *Some of my insperation...*
#
# - Exploring Transformer Text Generation for Medical Dataset Augmentation
#     https://www.aclweb.org/anthology/2020.lrec-1.578.pdf
#
#
# - Trouble on the Horizon: Forecasting the Derailment of Online Conversations as they Develop
#     https://arxiv.org/pdf/1909.01362.pdf
#
#
# - Automatic Detection of Incoherent Speech for Diagnosing Schizophrenia
#     https://nlp.stanford.edu/pubs/iter2018shizophrenia.pdf

# %% [markdown]
# <br><br>
# ___
#
# **Example:**
# *It is not acceptable for me that my insurance premiums were deducted from my biological mother's credit card, but only from my credit card. The court ruled that I did not need a guardian, and that if I did, then it must not be my biological mother. Honest and talented psychiatrists enough to write that I have never had schizophrenia. My biological mother tried to force me, of course against my will, to have incest with her. She also punished me for making a modest one-time donation, to elderly Holocaust survivors here in the country, for blankets, stoves, for winter heating, and for food and water, for those who could not afford them, and for the few modest donations, for clean water for bathing and drinking for children in Africa, and the one modest donation Once for food for poor families and orphaned children, here in Israel. My biological mother lied and slandered me, and paid bribes to corrupt cops, and corrupt doctors, To get me beaten to death, and much worse. Fifteen years ago, I was a student of the humanities and social sciences at Tel Aviv University, and a member of the social and political cell on the campus at the time, the 'National Liberal Moderate Right'. Prior to that, I successfully completed a series of courses at IBM. Before that, I graduated from Urban D High School, one year above Ayelet Ben Shaul Shaked. In the distant past, my mother was fine. My grandparents, on both sides, were good, honest, trustworthy, and talented people. And even wonderful. My biological mother, today, is not my mother, she behaves at best, like the cruel people of the PLO in the years 1970-1976. And maybe much worse than that. I asked for a restraining order against her. The Nazi regime in Germany, to European Jewry. As well as to millions of autistics, Latvians, and diagnosed with hysteria, and multiple sclerosis. Everything that Iran and ISIS want to do to all of us today, and what the PLO and KGB leaders wanted in the early 1970s to do not only to the State of Israel, and to all the Jews in the world, but also to everyone in Central and Western Europe, and the United States and Canada, including the West Coast The whole, and including the whole of Toronto, and the State of New York, the whole. Where's Lena Turner's daughter? I have never had a biological sister. And my daughter was never born. If I could go back to the statue of Juliette Verona now, I would no longer touch her tit, I would commit suicide. With such a biological mother. H E L P. What did I want to do? Live?*
#
# <br>
# What features could I see here?
# The sentences make sense, but the "connectivity" and the flow of the conversation going back and forth.
# So maybe I could use the "Sentences Flow" to measure the derriling.
# I can use BERT for this!
#
# For example:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This way I can change the Loss function for the generate model, and to create sentences that are "close" but not so much.
# The "how much" would have to be a hyperparameter for this POC, but latter could be used as an attention mechanism.

# %% [markdown]
# #### This method sounds close to a GAN network
#
# So let's create a GAN network using pytorch.
# I only did this using Keras, so it's gonna be a challenge..
#
# - Step 1: Train a NN to fit a Gaussian/Normal distribution using GAN architecture
# <a href='https://colab.research.google.com/drive/1RRkj7hcDvV0wWiKqemvTPltk4yyePfRk?usp=sharing'>Notebook</a>
# - Step 2: Train a NN to fit the MNIST dataset using GAN architecture <a href='https://colab.research.google.com/drive/1tB2Di_QlA6eULUQtiiAgXEtS8ae9InNf?usp=sharing'>Notebook</a>
#
# (also learned a lot about animation)
#
# <br>
#
# ### Further Works:
# Create a GAN, when G is GPT2 model and D is a BERT model.
# The D will measure the connectivity between the sentences.
#
# <br>
#
#
#
# ---
# Some of my insperation...
#
# Exploring Transformer Text Generation for Medical Dataset Augmentation
# https://www.aclweb.org/anthology/2020.lrec-1.578.pdf
#
# Trouble on the Horizon: Forecasting the Derailment of Online Conversations as they Develop
# https://arxiv.org/pdf/1909.01362.pdf
#
# Automatic Detection of Incoherent Speech for Diagnosing Schizophrenia
# https://nlp.stanford.edu/pubs/iter2018shizophrenia.pdf
#
# <br><br><br>
# <br><br><br>
# <br><br><br>

# %% [markdown]
# ### Goal #4 - Achieved!
# Let's crate a Chatbot to talk to.
#
# <br><br>
#
# <div>
# <img src="https://blog-assets.freshworks.com/freshdesk/wp-content/uploads/2018/08/Header_gif_assembly-1.gif" width="400"/>
# </div>
#
# <br><br>
#
# **Steps:**
# * Using NLTK to create a basic Chatbot.
# * Using BERT to create a Q&A Chatbot.
#
# <br>
#
# **Code**
# <a href='https://colab.research.google.com/drive/1vJp1Ukuq3UnsGHONRAorEqPRSpXCbgua?usp=sharing'>Colab Notebook</a>
#
# <br>
#
# **Conclusions:**
#
# There is still problems with the 'Final Model'.
# The Bot can answer questions, but not really talking.
#
# <br>

# %% [markdown]
# **Further work:**
# * Using BERT to create a Chatbot with personality.
# * Using BERT to create a Chabot that is Harry Potter.

# %% [markdown]
# **References**
#
# * <a href='https://huggingface.co/transformers/v2.11.0/pretrained_models.html'>Huggingface - Pretrained models</a>
#
#
# * <a href='https://rajpurkar.github.io/SQuAD-explorer/'>The Stanford Question Answering Dataset</a>
#
#
# * <a href='https://medium.com/analytics-vidhya/building-a-simple-chatbot-in-python-using-nltk-7c8c8215ac6e'>Building a Simple Chatbot from Scratch in Python</a>
#
#
# * <a href='https://towardsdatascience.com/how-to-train-your-chatbot-with-simple-transformers-da25160859f4
# '>
# How To Train Your Chatbot With Simple Transformers</a>
#
#
# * <a href='https://towardsdatascience.com/bert-nlp-how-to-build-a-question-answering-bot-98b1d1594d7b'>BERT NLP — How To Build a Question Answering Bot</a>
#
#
# * <a href='https://medium.com/huggingface/how-to-build-a-state-of-the-art-conversational-ai-with-transfer-learning-2d818ac26313
# '>How to build a State-of-the-Art Conversational AI with Transfer Learning</a>
